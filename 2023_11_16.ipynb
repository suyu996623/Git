# %% [markdown]
# <a href="https://colab.research.google.com/github/suyu996623/Git/blob/main/2023_11_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5,5,200)
y = np.sinc(x)

# %%
plt.plot(x,y)
